# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# combining the data of all the collected records from cardekho

# %%
df = pd.read_csv('cardekhobangalore.csv')

# %%
df1 = pd.read_csv('cardekhochennai.csv')

# %%
df2 = pd.read_csv('cardekhomumbai.csv')

# %%
df = df.append(df2)

# %%
df
# Out:
#                                   model    fuel          km   no of owner  \
# 0                   Maruti Alto 800 LXI  Petrol  42,096 kms   First Owner
# 1               Maruti Eeco 5 Seater AC  Petrol  57,129 kms   First Owner
# 2                    Maruti Celerio VXI  Petrol  23,666 kms   First Owner
# 3                Hyundai i10 Sportz 1.2  Petrol  24,613 kms   First Owner
# 4         Hyundai Santro GLS I - Euro I  Petrol  78,848 kms   First Owner
# ...                                 ...     ...         ...           ...
# 1432           Honda City i VTEC CVT VX  Petrol  79,000 kms  Second Owner
# 1433             Maruti Baleno Zeta 1.2  Petrol  18,000 kms   First Owner
# 1434  Hyundai Creta 1.6 VTVT AT SX Plus  Petrol  38,000 kms   First Owner
# 1435           Nissan Terrano XL 110 PS  Diesel  87,000 kms   First Owner
# 1436     Mercedes-Benz A-Class A200 CDI  Diesel  42,000 kms  Second Owner
#
#          yrs transmission        price
# 0     2018.0       Manual    3.2 Lakh*
# ...

# %%
df.to_csv(r'C:\Users\dell\Documents\ratingcsv\cardekhofinal1.csv',index=False,header=True)

# %% [markdown]
# combining data of olx in one dataset

# %%
df_n = pd.read_csv('olxaudi.csv')

# %%
df_n = df_n.append(df_n13)

# %%
df_n1 = pd.read_csv('olxford.csv')

# %%
df_n
# Out:
#      brand    model    fuel          km no of owner     yrs transmission  \
# 0     Audi     A8 L  Diesel   41,000 km         1st  2015.0    Automatic
# 1     Audi       A4  Diesel   90,000 km         2nd  2013.0    Automatic
# 2     Audi       Q3  Diesel   65,000 km         3rd  2013.0    Automatic
# 3     Audi       A4  Diesel   46,000 km         2nd  2014.0    Automatic
# 4     Audi       Q7  Diesel   60,000 km         1st  2014.0    Automatic
# ..     ...      ...     ...         ...         ...     ...          ...
# 595  Honda     City  Petrol   73,000 km         1st  2011.0       Manual
# 596  Skoda    Rapid  Diesel   44,000 km         1st  2018.0       Manual
# 597  Honda  City ZX  Diesel   70,000 km         2nd  2014.0       Manual
# 598  Skoda    Rapid  Petrol   32,000 km         1st  2017.0       Manual
# 599   2014    Rapid  Petrol  66000.0 km         1st  2014.0    Automatic
#
#            price
# 0    ₹ 48,95,000
# 1    ₹ 15,50,000
# 2    ₹ 13,50,000
# 3    ₹ 14,50,000
# ...

# %%
df_n.to_csv(r'C:\Users\dell\Documents\ratingcsv\olx.csv',index=False,header=True)

# %%
# separating model and brand
model = []
model = df['model']
model
# Out:
# 0                     Maruti Alto 800 LXI
# 1                 Maruti Eeco 5 Seater AC
# 2                      Maruti Celerio VXI
# 3                  Hyundai i10 Sportz 1.2
# 4           Hyundai Santro GLS I - Euro I
#                       ...
# 1432             Honda City i VTEC CVT VX
# 1433               Maruti Baleno Zeta 1.2
# 1434    Hyundai Creta 1.6 VTVT AT SX Plus
# 1435             Nissan Terrano XL 110 PS
# 1436       Mercedes-Benz A-Class A200 CDI
# Name: model, Length: 3117, dtype: object

# %%
brand = []

# %%
for i in model:
    j= ''                            
    j = i.split(" ")
    brand.append(j[0])

# %%
df['brand'] = brand

# %%
models = []

# %%
for i in model:
    j= ''                            
    j = i.split(" ")
    models.append(j[1])

# %%
df['models'] = models

# %%
df.drop('model',axis=1,inplace=True)

# %%
df = df.rename(columns={"models":"model"})

# %%
df  #separated value of brand and model from cardekho dataset
# Out:
#         fuel          km   no of owner     yrs transmission        price  \
# 0     Petrol  42,096 kms   First Owner  2018.0       Manual    3.2 Lakh*
# 1     Petrol  57,129 kms   First Owner  2018.0       Manual   3.75 Lakh*
# 2     Petrol  23,666 kms   First Owner  2016.0       Manual    3.7 Lakh*
# 3     Petrol  24,613 kms   First Owner  2016.0       Manual    4.1 Lakh*
# 4     Petrol  78,848 kms   First Owner  2008.0       Manual   1.75 Lakh*
# ...      ...         ...           ...     ...          ...          ...
# 1432  Petrol  79,000 kms  Second Owner  2014.0    Automatic   6.95 Lakh*
# 1433  Petrol  18,000 kms   First Owner  2018.0       Manual   6.75 Lakh*
# 1434  Petrol  38,000 kms   First Owner  2018.0    Automatic  14.11 Lakh*
# 1435  Diesel  87,000 kms   First Owner  2015.0       Manual    5.5 Lakh*
# 1436  Diesel  42,000 kms  Second Owner  2015.0    Automatic  15.25 Lakh*
#
#               brand    model
# 0            Maruti     Alto
# 1            Maruti     Eeco
# ...

# %%
df_n['no of owner'].value_counts()   #olx no of owner format
# Out:
# 1st    1144
# 2nd     538
# 3rd     117
# 4th      24
# 4+       10
# Name: no of owner, dtype: int64

# %%
df['no of owner'].value_counts()    #cardekho no of owner format
# Out:
# First Owner             2013
# Second Owner             665
# 1st Owner                289
# Third Owner               87
# 2nd Owner                 44
# Fourth & Above Owner      15
# Test Drive Car             3
# 3rd Owner                  1
# Name: no of owner, dtype: int64

# %%
import numpy as np

# %% [markdown]
# Making format of no of owner same for olx and cardekho

# %%
df['no of owner'] = np.where(df['no of owner']=='First Owner','1st',df['no of owner'])

# %%
df['no of owner'] = np.where(df['no of owner']=='Second Owner','2nd',df['no of owner'])

# %%
df['no of owner'] = np.where(df['no of owner']=='1st Owner','1st',df['no of owner'])

# %%
df['no of owner'] = np.where(df['no of owner']=='2nd Owner','2nd',df['no of owner'])

# %%
df['no of owner'] = np.where(df['no of owner']=='Third Owner','3rd',df['no of owner'])

# %%
df['no of owner'] = np.where(df['no of owner']=='3rd Owner','3rd',df['no of owner'])

# %%
df['no of owner'] = np.where(df['no of owner']=='Fourth & Above Owner','4+',df['no of owner'])

# %%
df['no of owner'] = np.where(df['no of owner']=='Test Drive Car','test',df['no of owner'])

# %%
df['no of owner'].value_counts()
# Out:
# 1st     2302
# 2nd      709
# 3rd       88
# 4+        15
# test       3
# Name: no of owner, dtype: int64

# %%
km = []
km = df['km']
km
# Out:
# 0       42,096 kms
# 1       57,129 kms
# 2       23,666 kms
# 3       24,613 kms
# 4       78,848 kms
#            ...
# 1432    79,000 kms
# 1433    18,000 kms
# 1434    38,000 kms
# 1435    87,000 kms
# 1436    42,000 kms
# Name: km, Length: 3117, dtype: object

# %%
kms = []

# %%
for i in km:
    j= ''                            
    j = i.split(" ")
    kms.append(j[0])

# %%
df['kms'] = kms

# %%
df.drop('km',axis=1,inplace=True)

# %%
price = []
price = df['price']
price
# Out:
# 0         3.2 Lakh*
# 1        3.75 Lakh*
# 2         3.7 Lakh*
# 3         4.1 Lakh*
# 4        1.75 Lakh*
#            ...
# 1432     6.95 Lakh*
# 1433     6.75 Lakh*
# 1434    14.11 Lakh*
# 1435      5.5 Lakh*
# 1436    15.25 Lakh*
# Name: price, Length: 3117, dtype: object

# %%
prices=[]
for i in price:
    j= ''                            
    j = i.split(" ")
    prices.append(j[0])

# %%
df['prices'] = prices

# %%
df.drop('price',axis=1,inplace=True)

# %% [markdown]
# Removing km and lakhs from the dataset

# %%
df
# Out:
#         fuel no of owner     yrs transmission          brand    model     kms  \
# 0     Petrol         1st  2018.0       Manual         Maruti     Alto  42,096
# 1     Petrol         1st  2018.0       Manual         Maruti     Eeco  57,129
# 2     Petrol         1st  2016.0       Manual         Maruti  Celerio  23,666
# 3     Petrol         1st  2016.0       Manual        Hyundai      i10  24,613
# 4     Petrol         1st  2008.0       Manual        Hyundai   Santro  78,848
# ...      ...         ...     ...          ...            ...      ...     ...
# 3112  Petrol         2nd  2014.0    Automatic          Honda     City  79,000
# 3113  Petrol         1st  2018.0       Manual         Maruti   Baleno  18,000
# 3114  Petrol         1st  2018.0    Automatic        Hyundai    Creta  38,000
# 3115  Diesel         1st  2015.0       Manual         Nissan  Terrano  87,000
# 3116  Diesel         2nd  2015.0    Automatic  Mercedes-Benz  A-Class  42,000
#
#      prices
# 0       3.2
# ...

# %%
df = pd.read_csv('cardekhofinal1.csv')

# %%
df1 = pd.read_csv('olxfinal.csv')

# %%
km = []
km = df1['km']
km
# Out:
# 0        41,000 km
# 1        90,000 km
# 2        65,000 km
# 3        46,000 km
# 4        60,000 km
#            ...
# 1995     73,000 km
# 1996     44,000 km
# 1997     70,000 km
# 1998     32,000 km
# 1999    66000.0 km
# Name: km, Length: 2000, dtype: object

# %%
kms=[]
for i in km:
    j= ''                            
    j = i.split(" ")
    kms.append(j[0])

# %%
df1['kms'] = kms

# %%
df1.drop('km',axis=1,inplace=True)

# %%
prices = []
prices = df1['price']
prices
# Out:
# 0       ₹ 48,95,000
# 1       ₹ 15,50,000
# 2       ₹ 13,50,000
# 3       ₹ 14,50,000
# 4       ₹ 25,25,000
#            ...
# 1995     ₹ 4,35,000
# 1996     ₹ 4,75,000
# 1997     ₹ 5,75,000
# 1998     ₹ 3,40,000
# 1999     ₹ 8,10,000
# Name: price, Length: 2000, dtype: object

# %%
pr = []
for i in prices:
    j= ''                            
    j = i.split(" ")
    pr.append(j[1])

# %%
df1['prices'] = pr

# %%
df1.drop('price',axis=1,inplace=True)

# %% [markdown]
# removing kms and rupees symbol from both the columns (olx dataset)

# %%
df1 = df1.append(df)

# %%
df1
# Out:
#               brand    model    fuel no of owner     yrs transmission     kms  \
# 0              Audi     A8 L  Diesel         1st  2015.0    Automatic  41,000
# 1              Audi       A4  Diesel         2nd  2013.0    Automatic  90,000
# 2              Audi       Q3  Diesel         3rd  2013.0    Automatic  65,000
# 3              Audi       A4  Diesel         2nd  2014.0    Automatic  46,000
# 4              Audi       Q7  Diesel         1st  2014.0    Automatic  60,000
# ...             ...      ...     ...         ...     ...          ...     ...
# 3112          Honda     City  Petrol         2nd  2014.0    Automatic  79,000
# 3113         Maruti   Baleno  Petrol         1st  2018.0       Manual  18,000
# 3114        Hyundai    Creta  Petrol         1st  2018.0    Automatic  38,000
# 3115         Nissan  Terrano  Diesel         1st  2015.0       Manual  87,000
# 3116  Mercedes-Benz  A-Class  Diesel         2nd  2015.0    Automatic  42,000
#
#          prices
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5117 entries, 0 to 3116
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         5040 non-null   object
#  1   model         5040 non-null   object
#  2   fuel          5027 non-null   object
#  3   no of owner   4950 non-null   object
#  4   yrs           5040 non-null   float64
#  5   transmission  5000 non-null   object
#  6   kms           5117 non-null   object
#  7   prices        5117 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 359.8+ KB

# %%
df1 = df.copy()

# %%
pd.set_option('display.max_rows',None)

# %% [markdown]
# Combining olx and cardekho dataset

# %%
df1
# Out:
#               brand             model           fuel no of owner     yrs  \
# 0              Audi              A8 L         Diesel         1st  2015.0
# 1              Audi                A4         Diesel         2nd  2013.0
# 2              Audi                Q3         Diesel         3rd  2013.0
# 3              Audi                A4         Diesel         2nd  2014.0
# 4              Audi                Q7         Diesel         1st  2014.0
# 5               NaN               NaN            NaN         NaN     NaN
# 6              Audi                A6         Diesel         1st  2014.0
# 7              Audi                A4         Diesel         1st  2014.0
# 8              Audi                Q3         Diesel         1st  2012.0
# 9              Audi                Q5         Diesel         1st  2012.0
# 10             Audi                A4         Petrol         2nd  2006.0
# 11             Audi               RS5         Petrol         2nd  2011.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Finding Null values in the dataset

# %%
df1.isnull().sum()
# Out:
# brand            77
# model            77
# fuel             90
# no of owner     167
# yrs              77
# transmission    117
# kms               0
# prices            0
# dtype: int64

# %%
import numpy as np

# %%
#replacing yes , brand , model with mode

df['brand'] = np.where(df['brand'].isnull(),df['brand'].mode(),df['brand'])
df['model'] = np.where(df['model'].isnull(),df['model'].mode(),df['model'])
df['yrs'] = np.where(df['yrs'].isnull(),df['yrs'].mode(),df['yrs'])

# %%
#creating new category for transmission , no of owner and fuel 
df['transmission'] = np.where(df['transmission'].isnull(),'Unknown_transmission',df['transmission'])
df['fuel'] = np.where(df['fuel'].isnull(),'Unknown_fuel',df['fuel'])
df['no of owner'] = np.where(df['no of owner'].isnull(),'Unknown_no of owner',df['no of owner'])

# %%
df.isnull().sum()
# Out:
# brand           0
# model           0
# fuel            0
# no of owner     0
# yrs             0
# transmission    0
# kms             0
# prices          0
# dtype: int64

# %%
price = []
price=  df["prices"]
price
# Out:
# 0       48,95,000
# 1       15,50,000
# 2       13,50,000
# 3       14,50,000
# 4       25,25,000
#           ...
# 5112         6.95
# 5113         6.75
# 5114        14.11
# 5115          5.5
# 5116        15.25
# Name: prices, Length: 5117, dtype: object

# %%
#remove ','  sign from the price symbol
pr = []
for i in price:
    j= ''                            
    j = i.replace(",","")
    pr.append(j)

# %%
df.drop('prices',axis=1,inplace=True)

# %%
km = []
km=  df["kms"]
km
# Out:
# 0       41,000
# 1       90,000
# 2       65,000
# 3       46,000
# 4       60,000
#          ...
# 5112    79,000
# 5113    18,000
# 5114    38,000
# 5115    87,000
# 5116    42,000
# Name: kms, Length: 5117, dtype: object

# %%
#removing ',' from kms column
k = []
for i in km:
    j= ''                            
    j = i.replace(",","")
    k.append(j)

# %%
df['kms'] = k

# %%
df.head()
# Out:
#   brand model    fuel no of owner     yrs transmission   prices    kms
# 0  Audi  A8 L  Diesel         1st  2015.0    Automatic  4895000  41000
# 1  Audi    A4  Diesel         2nd  2013.0    Automatic  1550000  90000
# 2  Audi    Q3  Diesel         3rd  2013.0    Automatic  1350000  65000
# 3  Audi    A4  Diesel         2nd  2014.0    Automatic  1450000  46000
# 4  Audi    Q7  Diesel         1st  2014.0    Automatic  2525000  60000

# %%
df = pd.read_csv('final_df.csv')

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['fuel'])
plt.show()
df['fuel'].value_counts()
# Out:
# Petrol           2489
# Diesel           2428
# Unknown_fuel       90
# CNG & Hybrids      72
# CNG                19
# LPG                17
# Electric            2
# Name: fuel, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['transmission'])
plt.show()
df['transmission'].value_counts()
# Out:
# Manual                  3518
# Automatic               1464
# Unknown_transmission     117
# MH03                       6
# MH01                       5
# MH13                       2
# MH04                       2
# MH02                       2
# MH46                       1
# Name: transmission, dtype: int64

# %% [markdown]
# #fuel used in cars are mostly petrol and discel
#
# #transmission is manual and automatic

# %%
#MH03 , MH01 ,MH13 ,MH04 ,MH02 MH06 are wrongs categories so replacing with Unknown_transmission
df['transmission'] = np.where(df['transmission']=='MH03','Unknown_transmission',df['transmission'])
df['transmission'] = np.where(df['transmission']=='MH01','Unknown_transmission',df['transmission'])
df['transmission'] = np.where(df['transmission']=='MH13','Unknown_transmission',df['transmission'])
df['transmission'] = np.where(df['transmission']=='MH04','Unknown_transmission',df['transmission'])
df['transmission'] = np.where(df['transmission']=='MH02','Unknown_transmission',df['transmission'])
df['transmission'] = np.where(df['transmission']=='MH46','Unknown_transmission',df['transmission'])

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['no of owner'])
plt.show()
df['no of owner'].value_counts()
# Out:
# 1st                    3446
# 2nd                    1247
# 3rd                     205
# Unknown_no of owner     167
# 4+                       25
# 4th                      24
# test                      3
# Name: no of owner, dtype: int64

# %% [markdown]
# Most of the cars are of first owner  , with manual transmission and fuel type of petrol or discel

# %%
df['brand'].value_counts()
# Out:
# Honda            722
# Maruti           642
# Ford             625
# Hyundai          608
# Maruti Suzuki    478
# Audi             436
# Toyota           232
# Mahindra         190
# Skoda            177
# Volkswagen       139
# Mercedes-Benz    107
# BMW               75
# 2016              69
# 2017              61
# Tata              59
# Renault           52
# 2015              50
# 2018              37
# Chevrolet         35
# 2014              33
# Nissan            31
# 2013              25
# Mini              25
# 2012              24
# 2019              23
# 2011              17
# Volvo             17
# Fiat              16
# Jeep              15
# 2020              10
# Datsun             9
# Jaguar             9
# 2010               9
# 2009               8
# Mitsubishi         6
# Land               6
# Kia                6
# Porsche            6
# 2008               5
# Ambassador         3
# 2007               3
# MG                 3
# 1.2 SV i VTEC      1
# ...

# %%
#dummy data in brand column :
#some unwanted data scraped in brand name
#replacing the dummy values with dummy values
df['brand'] = np.where(df['brand']=='2006','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='2013.0','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='2007','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='2008','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='1.8 S AT','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='2005','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='2009','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='VX i DTEC','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='2020','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='2016','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='2017','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='2011','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='2012','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='2013','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='2014','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='2015','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='2018','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='1.2 SV i VTEC','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='2004','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='2019','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='2010','dummy',df['brand'])
df['brand'] = np.where(df['brand']=='CVT i-vtec ','dummy',df['brand'])

# %%
#after replacing the dummy or wrong data
df['brand'].value_counts()
# Out:
# Honda            722
# Maruti           642
# Ford             625
# Hyundai          608
# Maruti Suzuki    478
# Audi             436
# dummy            381
# Toyota           232
# Mahindra         190
# Skoda            177
# Volkswagen       139
# Mercedes-Benz    107
# BMW               75
# Tata              59
# Renault           52
# Chevrolet         35
# Nissan            31
# Mini              25
# Volvo             17
# Fiat              16
# Jeep              15
# Jaguar             9
# Datsun             9
# Porsche            6
# Land               6
# Kia                6
# Mitsubishi         6
# MG                 3
# Ambassador         3
# Superb             1
# EXi                1
# Bentley            1
# CVT i-vtec         1
# OpelCorsa          1
# Hindustan          1
# Isuzu              1
# Name: brand, dtype: int64

# %%
plt.figure(figsize=(24,4))
sns.countplot(x='brand',hue='no of owner',data=df)
# Out:
# <AxesSubplot:xlabel='brand', ylabel='count'>

# %%
plt.figure(figsize=(24,4))
sns.countplot(x='brand',hue='transmission',data=df)
# Out:
# <AxesSubplot:xlabel='brand', ylabel='count'>

# %% [markdown]
# Audi provides automatic transmission ,
#
# and in other brands Manual transmission is freuquent

# %%
plt.figure(figsize=(24,4))
sns.countplot(x='brand',hue='fuel',data=df)
# Out:
# <AxesSubplot:xlabel='brand', ylabel='count'>

# %% [markdown]
# Audi , Honda , ford has discel cars and other has petrol fuel

# %%
plt.figure(figsize=(24,4))
sns.countplot(x='fuel',hue='transmission',data=df)
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='count'>

# %%
plt.figure(figsize=(24,4))
sns.countplot(x='fuel',hue='no of owner',data=df)
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='count'>

# %% [markdown]
# Most of the cars has petrol or discel ful type with first owner and manual transmission

# %% [markdown]
# Changing the datatype of km , prices and years column

# %%
df['kms'] = df['kms'].astype(float)

# %%
df['yrs'] = df['yrs'].astype(float)

# %%
df['prices'] = df['prices'].astype(int)

# %% [markdown]
# because of "*" values were not getting converted so replacing it with numeric value

# %%
df['prices'] = np.where(df['prices']=='75000*','75000',df['prices'])

# %%
df['prices'] = np.where(df['prices']=='94000*','94000',df['prices'])

# %%
df['prices'] = np.where(df['prices']=='90000*','90000',df['prices'])

# %%
df['prices'] = np.where(df['prices']=='85000*','85000',df['prices'])

# %%
df['prices'] = np.where(df['prices']=='99000*','99000',df['prices'])

# %%
df['prices'] = np.where(df['prices']=='80031*','80031',df['prices'])

# %%
df['prices'] = np.where(df['prices']=='55000*','55000',df['prices'])

# %%
df['prices'] = np.where(df['prices']=='98000*','98000',df['prices'])

# %%
df['prices'] = np.where(df['prices']=='89000*','89000',df['prices'])

# %%
df.groupby(df['yrs'])['prices'].median().plot.line()
# Out:
# <AxesSubplot:xlabel='yrs'>

# %% [markdown]
# cars of year between 2000 to 2020 have high prices

# %%
df.groupby(df['kms'])['prices'].median().plot.line()
# Out:
# <AxesSubplot:xlabel='kms'>

# %% [markdown]
# Price of car and kms are inversely correlated

# %%
df.head(3)
# Out:
#   brand model    fuel no of owner     yrs transmission     prices      kms
# 0  Audi  A8 L  Diesel         1st  2015.0    Automatic  4895000.0  41000.0
# 1  Audi    A4  Diesel         2nd  2013.0    Automatic  1550000.0  90000.0
# 2  Audi    Q3  Diesel         3rd  2013.0    Automatic  1350000.0  65000.0

# %%
plt.figure(figsize=(18,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Clearly seen km is inversely correlated and yrs is positively correlated with prices

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ord_en = OrdinalEncoder()                     #Encoded categorical variables through ordinal encoder
for i in df.columns:
    if(df[i].dtypes=='O'):
        df[i] = ord_en.fit_transform(df[i].values.reshape(-1,1))

# %%
from sklearn.preprocessing import StandardScaler

# %%
stnd_sc = StandardScaler()
df['prices'] = stnd_sc.fit_transform(df['prices'].values.reshape(-1,1))  #scaling target variable

# %%
from sklearn.preprocessing import MinMaxScaler
min_sc = MinMaxScaler()
df_n =  pd.DataFrame(min_sc.fit_transform(df),columns=df.columns)   #minmax for whole dataset

# %%
df_n.head()   #dataset after scaling and encoding
# Out:
#       brand     model      fuel  no of owner       yrs  transmission  \
# 0  0.028571  0.074890  0.333333     0.000000  0.950413           0.0
# 1  0.028571  0.052863  0.333333     0.166667  0.933884           0.0
# 2  0.028571  0.634361  0.333333     0.333333  0.933884           0.0
# 3  0.028571  0.052863  0.333333     0.166667  0.942149           0.0
# 4  0.028571  0.643172  0.333333     0.000000  0.942149           0.0
#
#      prices       kms
# 0  0.170261  0.006833
# 1  0.053913  0.015000
# 2  0.046956  0.010833
# 3  0.050435  0.007667
# 4  0.087826  0.010000

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x = df_n.drop('prices',axis=1)

# %%
y= df_n['prices']
# splitting dependent and independent variables

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
#finding best random state
for i in range(1,50):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.33,random_state=i)
    lr =  LinearRegression()
    lr.fit(x_train,y_train)
    pred_test = lr.predict(x_test)
    pred_train = lr.predict(x_train)
    if(round(mean_squared_error(pred_test,y_test)*100,1)==round(mean_squared_error(pred_train,y_train)*100,1)):
        print('random state',i)
        print('test mse',mean_squared_error(pred_test,y_test))
        print('train mse',mean_squared_error(pred_train,y_train))
# Out:
# random state 1
# test mse 0.0006258573789021943
# train mse 0.0009898503370731919
# random state 2
# test mse 0.0009269482424467053
# train mse 0.0008426477004732748
# random state 3
# test mse 0.0007239406232737395
# train mse 0.0009435351863036114
# random state 4
# test mse 0.0006143672650405287
# train mse 0.0009992615553628664
# random state 5
# test mse 0.0010067547706795932
# train mse 0.0008037733677313765
# random state 6
# test mse 0.0006248211176410013
# train mse 0.0009921742323339157
# random state 7
# test mse 0.0009746585237944963
# train mse 0.0008215452092230287
# random state 8
# test mse 0.0005959833664836217
# train mse 0.0010054908530566526
# random state 9
# test mse 0.0013485620772021136
# train mse 0.0006348472402137494
# random state 10
# test mse 0.0008123618692014544
# train mse 0.0008997379207698379
# random state 11
# test mse 0.0007488002732745787
# train mse 0.0009311426458798443
# random state 12
# test mse 0.0007836815344015163
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.33,random_state=5)

# %% [markdown]
# # Trying different algorithms

# %%
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
from sklearn.model_selection import cross_val_score

# %%
alg_l = [SVR,DecisionTreeRegressor,KNeighborsRegressor,LinearRegression]

# %%
for a in alg_l:
    x_train2,x_test2,y_train2,y_test2 = train_test_split(x,y,test_size=.33,random_state=5)
    obj_ = a()
    obj_.fit(x_train,y_train)
    p=obj_.predict(x_test)
    print(a)
    print("MSE",mean_squared_error(p,y_test))
    print("RMSE",np.sqrt(mean_squared_error(p,y_test)))
    print('........................')
# Out:
# <class 'sklearn.svm._classes.SVR'>
# MSE 0.0019890377848480636
# RMSE 0.04459862985393233
# ........................
# <class 'sklearn.tree._classes.DecisionTreeRegressor'>
# MSE 0.0009018923313461118
# RMSE 0.030031522294850652
# ........................
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'>
# MSE 0.0007689693223073661
# RMSE 0.027730296109262267
# ........................
# <class 'sklearn.linear_model._base.LinearRegression'>
# MSE 0.0010067547706795932
# RMSE 0.03172939915409041
# ........................

# %% [markdown]
# # Ensemble techniques

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
list_en = [RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor]

# %%
for i in list_en:
    ob = i(n_estimators=100)
    ob.fit(x_train,y_train)
    pr = ob.predict(x_test)
    cross_val = cross_val_score(ob,x,y,cv=4)
    print(i)
    print("MSE",mean_squared_error(p,y_test))
    print("RMSE",np.sqrt(mean_squared_error(p,y_test)))
    print('----------------------------------')
# Out:
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# MSE 0.0010067547706795932
# RMSE 0.03172939915409041
# ----------------------------------
# <class 'sklearn.ensemble._weight_boosting.AdaBoostRegressor'>
# MSE 0.0010067547706795932
# RMSE 0.03172939915409041
# ----------------------------------
# <class 'sklearn.ensemble._gb.GradientBoostingRegressor'>
# MSE 0.0010067547706795932
# RMSE 0.03172939915409041
# ----------------------------------

# %% [markdown]
# # Hyper parametric tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters_gb = {
    'n_estimators':[100,300,500],
    'max_depth':[4,5,6],
    'min_samples_split':[100,150]
}

# %%
grad_reg = GradientBoostingRegressor()
grid_gboost = GridSearchCV(grad_reg,parameters_gb,cv=5)
grid_gboost.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'max_depth': [4, 5, 6],
#                          'min_samples_split': [100, 150],
#                          'n_estimators': [100, 300, 500]})

# %%
print(grid_gboost.best_params_)
print(grid_gboost.best_score_)
# Out:
# {'max_depth': 6, 'min_samples_split': 100, 'n_estimators': 500}
# 0.7480992344510575

# %%
best_mod_gboost = GradientBoostingRegressor(n_estimators=300,min_samples_split=100,max_depth=6)

# %%
best_mod_gboost.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(max_depth=6, min_samples_split=100, n_estimators=300)

# %%
pred_final = best_mod_gboost.predict(x_test)

# %%
print('MSE of final Model',mean_squared_error(pred_final,y_test))
print('RMSE of final Model',np.sqrt(mean_squared_error(pred_final,y_test)))
# Out:
# MSE of final Model 0.0007137595788921159
# RMSE of final Model 0.0267162792860854

# %% [markdown]
# # Conclusion

# %%
original_res = np.array(y_test)
pred_res = np.array(best_mod_gboost.predict(x_test))
df_comparison = pd.DataFrame({'original':pred_res,'predicted':pred_res})
df_comparison
# Out:
#       original  predicted
# 0     0.001343   0.001343
# 1     0.016053   0.016053
# 2     0.016416   0.016416
# 3    -0.004027  -0.004027
# 4     0.006680   0.006680
# ...        ...        ...
# 1684  0.003479   0.003479
# 1685  0.023131   0.023131
# 1686  0.019809   0.019809
# 1687  0.021225   0.021225
# 1688  0.019958   0.019958
#
# [1689 rows x 2 columns]
