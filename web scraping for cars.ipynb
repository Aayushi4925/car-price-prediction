# %% [markdown]
# # Scraping data

# %%
import selenium
import pandas as pd
from selenium import webdriver

# %%
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Chrome(r"C:\Users\dell\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %% [markdown]
# # OLX

# %%
driver.get('https://www.olx.in/')

# %%
#navigating to the car page from main page
srch = driver.find_element_by_xpath('//div[@class="_3AGJR _18NX_"]/a')
srch.click()

# %%
search_bar = driver.find_element_by_xpath('//input[@data-aut-id="searchBox"]')
search_bar.send_keys('audi')   #entering the name of the brand

# %%
urls = []
for i in driver.find_elements_by_xpath('//li[@data-aut-id="itemBox"]/a'):     
    urls.append(i.get_attribute("href"))

# %%
brand_name = []
modl =[]
fuel_type = []
kilo = []
nofowner = []
years = []
transmisions = []

# %%
price = []
for i in driver.find_elements_by_xpath('//span[@class="_89yzn"]'):     
    price.append(i.text.replace('/n',''))

# %%
#audi
for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        p=driver.find_element_by_xpath('//span[@class="_2vNpt"][1]')
        brand_name.append(p.text.replace('/n',''))
    except NoSuchElementException:
        brand_name.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_model"]')
        modl.append(p.text.replace('/n',''))
    except NoSuchElementException:
        modl.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_variant"]')
        var.append(p.text.replace('/n',''))
    except NoSuchElementException:
        var.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_year"]')
        years.append(p.text.replace('/n',''))
    except NoSuchElementException:
        years.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_petrol"]')
        fuel_type.append(p.text.replace('/n',''))
    except NoSuchElementException:
        fuel_type.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_transmission"]')
        transmisions.append(p.text.replace('/n',''))
    except NoSuchElementException:
        transmisions.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_mileage"]')
        kilo.append(p.text.replace('/n',''))
    except NoSuchElementException:
        kilo.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_first_owner"]')
        nofowner.append(p.text.replace('/n',''))
    except NoSuchElementException:
        nofowner.append('NaN')

# %%
df = pd.DataFrame({})
df['brand']=brand_name
df['model']=modl
df['fuel']=fuel_type
df['km'] = kilo
df['no of owner'] = nofowner
df['yrs'] = years
df['transmission'] = transmisions
df['price'] = price
#saving data into the dataframe

# %%
search_bar = driver.find_element_by_xpath('//input[@data-aut-id="searchBox"]')
search_bar.send_keys('maruti')

# %%
urls = []
for i in driver.find_elements_by_xpath('//li[@data-aut-id="itemBox"]/a'):     
    urls.append(i.get_attribute("href"))  #finding the urls of all the pgs

# %%
#maruti
for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        p=driver.find_element_by_xpath('//span[@class="_2vNpt"][1]')
        brand_name.append(p.text.replace('/n',''))
    except NoSuchElementException:
        brand_name.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_model"]')
        modl.append(p.text.replace('/n',''))
    except NoSuchElementException:
        modl.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_year"]')
        years.append(p.text.replace('/n',''))
    except NoSuchElementException:
        years.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_petrol"]')
        fuel_type.append(p.text.replace('/n',''))
    except NoSuchElementException:
        fuel_type.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_transmission"]')
        transmisions.append(p.text.replace('/n',''))
    except NoSuchElementException:
        transmisions.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_mileage"]')
        kilo.append(p.text.replace('/n',''))
    except NoSuchElementException:
        kilo.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_first_owner"]')
        nofowner.append(p.text.replace('/n',''))
    except NoSuchElementException:
        nofowner.append('NaN')

# %%
price = []
for i in driver.find_elements_by_xpath('//span[@class="_89yzn"]'):     
    price.append(i.text.replace('/n',''))

# %%
df = pd.DataFrame({})
df['brand']=brand_name
df['model']=modl
df['fuel']=fuel_type
df['km'] = kilo
df['no of owner'] = nofowner
df['yrs'] = years
df['transmission'] = transmisions
df['price'] = price

# %%
search_bar = driver.find_element_by_xpath('//input[@data-aut-id="searchBox"]')
search_bar.send_keys('ford')

# %%
urls = []
for i in driver.find_elements_by_xpath('//li[@data-aut-id="itemBox"]/a'):     
    urls.append(i.get_attribute("href"))

# %%
price = []
for i in driver.find_elements_by_xpath('//span[@class="_89yzn"]'):     
    price.append(i.text.replace('/n',''))

# %%
for i in urls:
    driver.get(i)
    time.sleep(2)
    try:
        p=driver.find_element_by_xpath('//span[@class="_2vNpt"][1]')
        brand_name.append(p.text.replace('/n',''))
    except NoSuchElementException:
        brand_name.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_model"]')
        modl.append(p.text.replace('/n',''))
    except NoSuchElementException:
        modl.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_year"]')
        years.append(p.text.replace('/n',''))
    except NoSuchElementException:
        years.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_petrol"]')
        fuel_type.append(p.text.replace('/n',''))
    except NoSuchElementException:
        fuel_type.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_transmission"]')
        transmisions.append(p.text.replace('/n',''))
    except NoSuchElementException:
        transmisions.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_mileage"]')
        kilo.append(p.text.replace('/n',''))
    except NoSuchElementException:
        kilo.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_first_owner"]')
        nofowner.append(p.text.replace('/n',''))
    except NoSuchElementException:
        nofowner.append('NaN')

# %%
df = pd.DataFrame({})
df['brand']=brand_name
df['model']=modl
df['fuel']=fuel_type
df['km'] = kilo
df['no of owner'] = nofowner
df['yrs'] = years
df['transmission'] = transmisions
df['price'] = price

# %%
search_bar = driver.find_element_by_xpath('//input[@data-aut-id="searchBox"]')
search_bar.send_keys('honda')

# %%
#honda 
urls = []
for i in driver.find_elements_by_xpath('//li[@data-aut-id="itemBox"]/a'):     
    urls.append(i.get_attribute("href"))

# %%
for i in urls:
    driver.get(i)
    time.sleep(2)
    try:
        p=driver.find_element_by_xpath('//span[@class="_2vNpt"][1]')
        brand_name.append(p.text.replace('/n',''))
    except NoSuchElementException:
        brand_name.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_model"]')
        modl.append(p.text.replace('/n',''))
    except NoSuchElementException:
        modl.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_year"]')
        years.append(p.text.replace('/n',''))
    except NoSuchElementException:
        years.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_petrol"]')
        fuel_type.append(p.text.replace('/n',''))
    except NoSuchElementException:
        fuel_type.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_transmission"]')
        transmisions.append(p.text.replace('/n',''))
    except NoSuchElementException:
        transmisions.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_mileage"]')
        kilo.append(p.text.replace('/n',''))
    except NoSuchElementException:
        kilo.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@data-aut-id="value_first_owner"]')
        nofowner.append(p.text.replace('/n',''))
    except NoSuchElementException:
        nofowner.append('NaN')

# %%
price = []
for i in driver.find_elements_by_xpath('//span[@class="_89yzn"]'):     
    price.append(i.text.replace('/n',''))

# %%
df = pd.DataFrame({})
df['brand']=brand_name
df['model']=modl
df['fuel']=fuel_type
df['km'] = kilo
df['no of owner'] = nofowner
df['yrs'] = years
df['transmission'] = transmisions
df['price'] = price

# %%
df.to_csv(r'C:\Users\dell\Documents\ratingcsv\olx.csv',index=False,header=True)  #saving data

# %%
df
# Out:
#      brand    model    fuel          km no of owner     yrs transmission  \
# 0    Skoda     Yeti  Diesel   51,914 km         1st  2013.0       Manual
# 1    Honda   Accord  Petrol   67,000 km         2nd  2013.0    Automatic
# 2    Honda  Mobilio  Diesel   83,300 km         1st  2016.0       Manual
# 3    Skoda    Rapid  Diesel   74,000 km         1st  2014.0       Manual
# 4    Skoda    Laura  Diesel   63,000 km         1st  2010.0    Automatic
# ..     ...      ...     ...         ...         ...     ...          ...
# 595  Honda     City  Petrol   73,000 km         1st  2011.0       Manual
# 596  Skoda    Rapid  Diesel   44,000 km         1st  2018.0       Manual
# 597  Honda  City ZX  Diesel   70,000 km         2nd  2014.0       Manual
# 598  Skoda    Rapid  Petrol   32,000 km         1st  2017.0       Manual
# 599   2014    Rapid  Petrol  66000.0 km         1st  2014.0    Automatic
#
#           price
# 0    ₹ 4,25,000
# 1    ₹ 3,25,000
# 2    ₹ 5,57,000
# 3    ₹ 5,75,000
# ...

# %% [markdown]
# # Cardekho

# %%
driver.get('https://www.cardekho.com/')

# %%
search_bar = driver.find_element_by_id('cardekhosearchtext')
search_bar.send_keys('ahmdabad') #entering location in the search bar

# %%
cl = driver.find_element_by_xpath('//button[@class="searchbtn"]')
cl.click()   #clicking on the search bar

# %%
urls = []
for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7 carsName"]/a'):     
    urls.append(i.get_attribute("href"))

# %%
price = []
yrs = []

fuels = []
owners = []
trans = []
kms = []
models = []

# %%
for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        p=driver.find_element_by_xpath('//div[@class="vdp-head"]/h1[2]')
        model.append(p.text.replace('/n',''))
    except NoSuchElementException:
        model.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@class="pricewrapper posR"]/span[1]')
        prices.append(p.text.replace('/n',''))
    except NoSuchElementException:
        prices.append('NaN')
    try:
        p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[1]/div[1]/div')
        yr.append(p.text.replace('/n',''))
    except NoSuchElementException:
        yr.append('NaN')
    try:
        p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[5]/div[1]/div')
        fuel.append(p.text.replace('/n',''))
    except NoSuchElementException:
        fuel.append('NaN')
    try:
        p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[3]/div[1]/div')
        km.append(p.text.replace('/n',''))
    except NoSuchElementException:
        km.append('NaN')
    try:
        p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[4]/div[1]/div')
        owner.append(p.text.replace('/n',''))
    except NoSuchElementException:
        owner.append('NaN')
    try:
        p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[6]/div[1]/div')
        tran.append(p.text.replace('/n',''))
    except NoSuchElementException:
        tran.append('NaN')

# %%
df = pd.DataFrame({})
df['model']=model
df['fuel']=fuel
df['km'] = km
df['no of owner'] = owner
df['yrs'] = yr
df['transmission'] = tran
df['price'] = prices

# %%
search_bar = driver.find_element_by_id('cardekhosearchtext')
search_bar.send_keys('bangalore') #entering location in the search bar

# %%
cl = driver.find_element_by_xpath('//button[@class="searchbtn"]')
cl.click()

# %%
urls = []
for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7 carsName"]/a'):     
    urls.append(i.get_attribute("href"))

# %%
for i in u:
    driver.get(i)
    time.sleep(2)
    try:
        p=driver.find_element_by_xpath('//div[@class="vdp-head"]/h1[2]')
        model.append(p.text.replace('/n',''))
    except NoSuchElementException:
        model.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@class="pricewrapper posR"]/span[1]')
        prices.append(p.text.replace('/n',''))
    except NoSuchElementException:
        prices.append('NaN')
    try:
        p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[1]/div[1]/div')
        yr.append(p.text.replace('/n',''))
    except NoSuchElementException:
        yr.append('NaN')
    try:
        p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[5]/div[1]/div')
        fuel.append(p.text.replace('/n',''))
    except NoSuchElementException:
        fuel.append('NaN')
    try:
        p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[3]/div[1]/div')
        km.append(p.text.replace('/n',''))
    except NoSuchElementException:
        km.append('NaN')
    try:
        p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[4]/div[1]/div')
        owner.append(p.text.replace('/n',''))
    except NoSuchElementException:
        owner.append('NaN')
    try:
        p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[6]/div[1]/div')
        tran.append(p.text.replace('/n',''))
    except NoSuchElementException:
        tran.append('NaN')

# %%
df = pd.DataFrame({})
df['model']=model
df['fuel']=fuel
df['km'] = km
df['no of owner'] = owner
df['yrs'] = yr
df['transmission'] = tran
df['price'] = prices

# %%
search_bar = driver.find_element_by_id('cardekhosearchtext')
search_bar.send_keys('chennai')

# %%
cl = driver.find_element_by_xpath('//button[@class="searchbtn"]')
cl.click()

# %%
#chennai
url = []
for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7 carsName"]/a'):     
    url.append(i.get_attribute("href"))

# %%
for i in ur:
    driver.get(i)
    time.sleep(2)
    try:
        p=driver.find_element_by_xpath('//div[@class="vdp-head"]/h1[2]')
        models.append(p.text.replace('/n',''))
    except NoSuchElementException:
        models.append('NaN')
    try:
        p=driver.find_element_by_xpath('//span[@class="pricewrapper posR"]/span[1]')
        price.append(p.text.replace('/n',''))
    except NoSuchElementException:
        price.append('NaN')
    try:
        p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[1]/div[1]/div')
        yrs.append(p.text.replace('/n',''))
    except NoSuchElementException:
        yrs.append('NaN')
    try:
        p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[5]/div[1]/div')
        fuels.append(p.text.replace('/n',''))
    except NoSuchElementException:
        fuels.append('NaN')
    try:
        p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[3]/div[1]/div')
        kms.append(p.text.replace('/n',''))
    except NoSuchElementException:
        kms.append('NaN')
    try:
        p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[4]/div[1]/div')
        owners.append(p.text.replace('/n',''))
    except NoSuchElementException:
        owners.append('NaN')
    try:
        p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[6]/div[1]/div')
        trans.append(p.text.replace('/n',''))
    except NoSuchElementException:
        trans.append('NaN')

# %%
df = pd.DataFrame({})
df['model']=models
df['fuel']=fuels
df['km'] = kms
df['no of owner'] = owners
df['yrs'] = yrs
df['transmission'] = trans
df['price'] = price

# %%
df
# Out:
#                                    model    fuel          km  no of owner  \
# 0                    Maruti Alto 800 LXI  Petrol  42,096 kms  First Owner
# 1                Maruti Eeco 5 Seater AC  Petrol  57,129 kms  First Owner
# 2                     Maruti Celerio VXI  Petrol  23,666 kms  First Owner
# 3                 Hyundai i10 Sportz 1.2  Petrol  24,613 kms  First Owner
# 4          Hyundai Santro GLS I - Euro I  Petrol  78,848 kms  First Owner
# ...                                  ...     ...         ...          ...
# 1036  Maruti Eeco 7 Seater Standard BSIV  Petrol  70,000 kms  First Owner
# 1037            Honda City i-VTEC CVT ZX  Petrol  26,070 kms  First Owner
# 1038               Hyundai i10 Magna 1.2  Petrol  51,000 kms  First Owner
# 1039               Maruti Swift LXi BSIV  Petrol  35,000 kms  First Owner
# 1040                    Maruti Swift LXI  Petrol   5,000 kms  First Owner
#
#        yrs transmission       price
# 0     2018       Manual   3.2 Lakh*
# ...

# %%
search_bar = driver.find_element_by_id('cardekhosearchtext')
search_bar.send_keys('mumbai')

# %%
cl = driver.find_element_by_xpath('//button[@class="searchbtn"]')
cl.click()

# %%
#Mumbai
urls = []
for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7 carsName"]/a'):     
    urls.append(i.get_attribute("href"))

# %%
prices = []
yr = []
fuel = []
owner = []
tran = []
km = []
model = []

# %%
for i in urls:
    driver.get(i)
    time.sleep(2)
    try:
        try:
            p=driver.find_element_by_xpath('//div[@class="vdp-head"]/h1[2]')
            model.append(p.text.replace('/n',''))
        except:
            p=driver.find_element_by_xpath('//div[@class="paddingBorder clearfix"]/div[1]/h1[1]')
            model.append(p.text.replace('/n',''))
    except NoSuchElementException:
        model.append('NaN')
    try:
        try:
            p=driver.find_element_by_xpath('//span[@class="pricewrapper posR"]/span[1]')
            prices.append(p.text.replace('/n',''))
        except:
            p=driver.find_element_by_xpath('//div[@class="priceSection"]/span[2]')
            prices.append(p.text.replace('/n',''))
    except NoSuchElementException:
        prices.append('NaN')
    try:
        try:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[1]/div[1]/div')
            yr.append(p.text.replace('/n',''))
        except:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[1]/div[1]/div[2]')
            yr.append(p.text.replace('/n',''))
    except NoSuchElementException:
        yr.append('NaN')
    try:
        try:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[5]/div[1]/div')
            fuel.append(p.text.replace('/n',''))
        except:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[3]/div[1]/div[2]')
            fuel.append(p.text.replace('/n',''))
    except NoSuchElementException:
        fuel.append('NaN')
    try:
        try:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[3]/div[1]/div')
            km.append(p.text.replace('/n',''))
        except:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[4]/div[1]/div[2]')
            km.append(p.text.replace('/n',''))
    except NoSuchElementException:
        km.append('NaN')
    try:
        try:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[4]/div[1]/div')
            owner.append(p.text.replace('/n',''))
        except:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[6]/div[1]/div[2]')
            owner.append(p.text.replace('/n',''))
    except NoSuchElementException:
        owner.append('NaN')
    try:
        try:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[6]/div[1]/div')
            tran.append(p.text.replace('/n',''))
        except:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[8]/div[1]/div[2]')
            tran.append(p.text.replace('/n',''))
    except NoSuchElementException:
        tran.append('NaN')

# %%
for i in urls:
    driver.get(i)
    time.sleep(2)
    try:
        p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[1]/div[1]/div')
        yrs.append(p.text.replace('/n',''))
    except:
        p=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[1]/div[1]/div[2]')
        yrs.append(p.text.replace('/n',''))

# %%
df = pd.DataFrame({})
df['model']=model
df['fuel']=fuel
df['km'] = km
df['no of owner'] = owner
df['yrs'] = yr
df['transmission'] = tran
df['price'] = prices

# %%
df.to_csv(r'C:\Users\dell\Documents\ratingcsv\cardekho.csv',index=False,header=True)  #saving for future

# %%
df
# Out:
#                                   model    fuel           km   no of owner  \
# 0                   2014 Maruti Celerio  Petrol   38,828 Kms     1st Owner
# 1                    2015 Hyundai Xcent  Petrol   33,567 Kms     1st Owner
# 2                    2012 Hyundai Verna  Diesel   85,295 Kms     2nd Owner
# 3                      2015 Hyundai i20  Diesel  103,266 Kms     1st Owner
# 4                 2014 Volkswagen Vento  Diesel   79,613 Kms     1st Owner
# ...                                 ...     ...          ...           ...
# 1432           Honda City i VTEC CVT VX  Petrol   79,000 kms  Second Owner
# 1433             Maruti Baleno Zeta 1.2  Petrol   18,000 kms   First Owner
# 1434  Hyundai Creta 1.6 VTVT AT SX Plus  Petrol   38,000 kms   First Owner
# 1435           Nissan Terrano XL 110 PS  Diesel   87,000 kms   First Owner
# 1436     Mercedes-Benz A-Class A200 CDI  Diesel   42,000 kms  Second Owner
#
#        yrs transmission        price
# ...

# %%
search_bar = driver.find_element_by_id('cardekhosearchtext')
search_bar.send_keys('mumbai')
cl = driver.find_element_by_xpath('//button[@class="searchbtn"]')
cl.click()

# %%
urls = []
for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7 carsName"]/a'):     
    urls.append(i.get_attribute("href"))

# %%
for i in urls:
    driver.get(i)
    time.sleep(2)
    try:
        try:
            p=driver.find_element_by_xpath('//div[@class="vdp-head"]/h1[2]')
            model.append(p.text.replace('/n',''))
        except:
            p=driver.find_element_by_xpath('//div[@class="paddingBorder clearfix"]/div[1]/h1[1]')
            model.append(p.text.replace('/n',''))
    except NoSuchElementException:
        model.append('NaN')
    try:
        try:
            p=driver.find_element_by_xpath('//span[@class="pricewrapper posR"]/span[1]')
            prices.append(p.text.replace('/n',''))
        except:
            p=driver.find_element_by_xpath('//div[@class="priceSection"]/span[2]')
            prices.append(p.text.replace('/n',''))
    except NoSuchElementException:
        prices.append('NaN')
    try:
        try:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[1]/div[1]/div')
            yr.append(p.text.replace('/n',''))
        except:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[1]/div[1]/div[2]')
            yr.append(p.text.replace('/n',''))
    except NoSuchElementException:
        yr.append('NaN')
    try:
        try:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[5]/div[1]/div')
            fuel.append(p.text.replace('/n',''))
        except:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[3]/div[1]/div[2]')
            fuel.append(p.text.replace('/n',''))
    except NoSuchElementException:
        fuel.append('NaN')
    try:
        try:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[3]/div[1]/div')
            km.append(p.text.replace('/n',''))
        except:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[4]/div[1]/div[2]')
            km.append(p.text.replace('/n',''))
    except NoSuchElementException:
        km.append('NaN')
    try:
        try:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[4]/div[1]/div')
            owner.append(p.text.replace('/n',''))
        except:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[6]/div[1]/div[2]')
            owner.append(p.text.replace('/n',''))
    except NoSuchElementException:
        owner.append('NaN')
    try:
        try:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row clearfix"]/li[6]/div[1]/div')
            tran.append(p.text.replace('/n',''))
        except:
            p=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[8]/div[1]/div[2]')
            tran.append(p.text.replace('/n',''))
    except NoSuchElementException:
        tran.append('NaN')

# %%
df = pd.DataFrame({})
df['model']=model
df['fuel']=fuel
df['km'] = km
df['no of owner'] = owner
df['yrs'] = yr
df['transmission'] = tran
df['price'] = prices

# %%
df
# Out:
#                            model    fuel          km   no of owner   yrs  \
# 0           2014 Maruti Alto 800  Petrol  40,167 Kms     1st Owner  2013
# 1         2015 Hyundai Grand i10  Petrol  39,886 Kms     1st Owner  2015
# 2         2016 Hyundai Grand i10  Diesel  63,759 Kms     2nd Owner  2016
# 3              2020 Renault KWID  Petrol  15,900 Kms     1st Owner  2020
# 4                2019 Tata Tiago  Petrol  20,463 Kms     1st Owner  2018
# ..                           ...     ...         ...           ...   ...
# 631              Honda Brio S MT  Petrol  55,000 kms   First Owner  2015
# 632           Mahindra Thar CRDe  Diesel  61,700 kms   First Owner  2016
# 633    Audi A8 L 3.0 TDI quattro  Diesel  27,000 kms   First Owner  2012
# 634          Honda City 1.5 V MT  Petrol  64,000 kms   First Owner  2011
# 635  BMW X3 xDrive20d Expedition  Diesel  55,000 kms  Second Owner  2014
#
#     transmission        price
# 0         Manual     1,92,500
# ...

# %%
df.to_csv(r'C:\Users\dell\Documents\ratingcsv\cardekho2.csv',index=False,header=True)  #saving for future

# %% [markdown]
# # Cars24

# %%
driver.get('https://www.cars24.com/')

# %%
#moving to the car navigation page
buycars = driver.find_element_by_xpath('//ul[@class="float-right _1yq3e"]/li[3]/a')    
driver.get(buycars.get_attribute("href"))

# %%
url = []
for i in driver.find_elements_by_xpath('//a[@class="_9Ue0B"]'):     
    url.append(i.get_attribute("href"))

# %%
#name , year and model in one column

modl = []
k = []
trns = []
ownrs = []
prics = []

# %%
fuls = []

# %%
for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        p=driver.find_element_by_xpath('//div[@class="_187DF"]/div[2]/h2[1]')
        modl.append(p.text.replace('/n',''))
    except NoSuchElementException:
        modl.append('NaN')
    try:
        p=driver.find_element_by_xpath('//div[@class="_187DF"]/div[3]/strong')
        prics.append(p.text.replace('/n',''))
    except NoSuchElementException:
        prics.append('NaN')
    try:
        try:
            p=driver.find_element_by_xpath('//strong[@class="_1-PH2"][4]')
            fuls.append(p.text.replace('/n',''))
        except:
            p=driver.find_element_by_xpath('//li[@class="tHlIu"][4]/strong[1]')
            fuls.append(p.text.replace('/n',''))
    except NoSuchElementException:
        fuls.append('NaN')
    try:
        try:
            p=driver.find_element_by_xpath('//strong[@class="_1-PH2"][3]')
            k.append(p.text.replace('/n',''))
        except:
            p=driver.find_element_by_xpath('//li[@class="tHlIu"][3]/strong[1]')
            k.append(p.text.replace('/n',''))
    except NoSuchElementException:
        k.append('NaN')
    try:
        try:
            p=driver.find_element_by_xpath('//strong[@class="_1-PH2"][2]')
            ownrs.append(p.text.replace('/n',''))
        except:
            p=driver.find_element_by_xpath('//li[@class="tHlIu"][2]/strong[1]')
            ownrs.append(p.text.replace('/n',''))
    except NoSuchElementException:
        ownrs.append('NaN')
    try:
        try:
            p=driver.find_element_by_xpath('//strong[@class="_1-PH2"][6]')
            trns.append(p.text.replace('/n',''))
        except:
            p=driver.find_element_by_xpath('//li[@class="tHlIu"][6]/strong[1]')
            trns.append(p.text.replace('/n',''))
    except NoSuchElementException:
        trns.append('NaN')

# %%
len(trns)
# Out:
# 292

# %%
df = pd.DataFrame({})
df['model']=modl
df['fuel']=fuls
df['km'] = k
df['no of owner'] = ownrs
df['transmission'] = trns
df['price'] = prics

# %%
df
# Out:
#                                        model    fuel         km no of owner  \
# 0          2021 Hyundai VENUE S MT 1.2 KAPPA  Petrol   2,589 km   1st Owner
# 1    2020 Maruti Baleno DELTA 1.2 K12 MANUAL  Petrol   3,920 km   1st Owner
# 2     2020 Maruti IGNIS SIGMA 1.2 K12 MANUAL  Petrol   2,206 km   1st Owner
# 3               2013 Maruti Swift VDI MANUAL  Diesel  11,019 km   1st Owner
# 4            2013 Maruti Alto 800 LXI MANUAL  Petrol   8,967 km   1st Owner
# ..                                       ...     ...        ...         ...
# 287       2018 Maruti Wagon R 1.0 VXI MANUAL  Petrol  36,481 km   1st Owner
# 288                                      NaN  Petrol  10,618 km   1st Owner
# 289                                      NaN  Petrol  20,883 km   1st Owner
# 290                                      NaN  Diesel  57,728 km   1st Owner
# 291         2017 Maruti Swift VDI ABS MANUAL  Diesel  73,900 km   1st Owner
#
#      transmission      price
# ...

# %%
df.to_csv(r'C:\Users\dell\Documents\ratingcsv\car24.csv',index=False,header=True)
